# %%
# !pip3 install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.5.0.20230113-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.5.0.20230113

# %%
# importing libraries and packages
import os
import pandas as pd
import datetime
import snscrape.modules.twitter as sntwitter
from pytz import timezone

# Define the keywords and date range
keywords = ['Us Healthcare', '#Ushealthcare', 'Medicaid', 'medicare', 'tricare', 'veterans care', 'medical debt', 'medical Cost', '#Medicaid', '#medicare', '#tricare', '#veterans care', '#medicaldebt', '#medicalcost']
start_date = '2021-01-01'
end_date = '2022-12-31'

# Define the output directory
output_dir = '/content/drive/MyDrive/colabDatasets/Twitter_tweets_Thesis/Mined By Date/Month Interated'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print('Directory Not Present : Creating')

# Define the progress file
progress_file = os.path.join(output_dir, 'progress.csv')
progress_df = pd.DataFrame(columns=['Month', 'Keyword', 'Tweets'])

# If the progress file exists, read it and resume job
if os.path.exists(progress_file):
    progress_df = pd.read_csv(progress_file)
    print('Directory Present : Reading Progress Tracker')
    print('Resuming Job')

# Iterate through the keywords
for keyword in keywords:
    print('Mining tweets for keyword:', keyword)
    # Iterate through each month in the date range
    start_month = datetime.datetime.strptime(start_date, '%Y-%m-%d').date().replace(day=1)
    end_month = datetime.datetime.strptime(end_date, '%Y-%m-%d').date().replace(day=1)
    for month in pd.date_range(start=start_month, end=end_month, freq='MS'):
        print('Mining tweets for month:', month.strftime('%Y-%m'))
        # If  already mined this keyword for this month, skip it
        if not progress_df.loc[(progress_df['Keyword'] == keyword) & (progress_df['Month'] == month.strftime('%Y-%m'))].empty:
            print(f'Skipping {keyword} for {month.strftime("%Y-%m")} as it has already been mined')
            continue
        # Define the file path for this keyword and month
        file_name = f"{month.strftime('%Y-%m')}_{keyword}.xlsx"
        file_path = os.path.join(output_dir, file_name)
        # Using TwitterSearchScraper to scrape data and append tweets to list
        tweets_list = []
        for i, tweet in enumerate(sntwitter.TwitterSearchScraper(f'{keyword} since:{month.strftime("%Y-%m-%d")} until:{(month + pd.DateOffset(months=1)).strftime("%Y-%m-%d")}').get_items()):
            
            #if i >= 30:
            #    break
            # Convert datetime to timezone-naive datetime
            tweet_date = tweet.date.astimezone(timezone('UTC')).replace(tzinfo=None)
            tweets_list.append([tweet_date, tweet.id, tweet.content, tweet.username])
        # Creating a dataframe from the tweets list above
        tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
        # Save the dataframe to Excel file
        tweets_df.to_excel(file_path, index=False)
        print(f'Saved {len(tweets_list)} tweets for {keyword} in {month.strftime("%Y-%m")} to file')
        # Record the number of tweets in the progress file
        tweets_count = len(tweets_list)
        progress_df = progress_df.append({'Month': month.strftime('%Y-%m'), 'Keyword': keyword, 'Tweets': tweets_count}, ignore_index=True)
        progress_df.to_csv(progress_file, index=False)
# Out:
# Directory Present : Reading Progress Tracker
# Resuming Job
# Mining tweets for keyword: Us Healthcare
# Mining tweets for month: 2021-01
# Skipping Us Healthcare for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping Us Healthcare for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping Us Healthcare for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping Us Healthcare for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping Us Healthcare for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping Us Healthcare for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping Us Healthcare for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping Us Healthcare for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping Us Healthcare for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping Us Healthcare for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping Us Healthcare for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping Us Healthcare for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping Us Healthcare for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping Us Healthcare for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping Us Healthcare for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping Us Healthcare for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping Us Healthcare for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping Us Healthcare for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping Us Healthcare for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping Us Healthcare for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping Us Healthcare for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping Us Healthcare for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping Us Healthcare for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping Us Healthcare for 2022-12 as it has already been mined
# Mining tweets for keyword: #Ushealthcare
# Mining tweets for month: 2021-01
# Skipping #Ushealthcare for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping #Ushealthcare for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping #Ushealthcare for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping #Ushealthcare for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping #Ushealthcare for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping #Ushealthcare for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping #Ushealthcare for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping #Ushealthcare for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping #Ushealthcare for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping #Ushealthcare for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping #Ushealthcare for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping #Ushealthcare for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping #Ushealthcare for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping #Ushealthcare for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping #Ushealthcare for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping #Ushealthcare for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping #Ushealthcare for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping #Ushealthcare for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping #Ushealthcare for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping #Ushealthcare for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping #Ushealthcare for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping #Ushealthcare for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping #Ushealthcare for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping #Ushealthcare for 2022-12 as it has already been mined
# Mining tweets for keyword: Medicaid
# Mining tweets for month: 2021-01
# Skipping Medicaid for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping Medicaid for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping Medicaid for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping Medicaid for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping Medicaid for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping Medicaid for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping Medicaid for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping Medicaid for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping Medicaid for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping Medicaid for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping Medicaid for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping Medicaid for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping Medicaid for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping Medicaid for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping Medicaid for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping Medicaid for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping Medicaid for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping Medicaid for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping Medicaid for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping Medicaid for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping Medicaid for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping Medicaid for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping Medicaid for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping Medicaid for 2022-12 as it has already been mined
# Mining tweets for keyword: medicare
# Mining tweets for month: 2021-01
# Skipping medicare for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping medicare for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping medicare for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping medicare for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping medicare for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping medicare for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping medicare for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping medicare for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping medicare for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping medicare for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping medicare for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping medicare for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping medicare for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping medicare for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping medicare for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping medicare for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping medicare for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping medicare for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping medicare for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping medicare for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping medicare for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping medicare for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping medicare for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping medicare for 2022-12 as it has already been mined
# Mining tweets for keyword: tricare
# Mining tweets for month: 2021-01
# Skipping tricare for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping tricare for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping tricare for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping tricare for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping tricare for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping tricare for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping tricare for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping tricare for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping tricare for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping tricare for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping tricare for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping tricare for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping tricare for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping tricare for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping tricare for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping tricare for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping tricare for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping tricare for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping tricare for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping tricare for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping tricare for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping tricare for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping tricare for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping tricare for 2022-12 as it has already been mined
# Mining tweets for keyword: veterans care
# Mining tweets for month: 2021-01
# Skipping veterans care for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping veterans care for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping veterans care for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping veterans care for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping veterans care for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping veterans care for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping veterans care for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping veterans care for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping veterans care for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping veterans care for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping veterans care for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping veterans care for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping veterans care for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping veterans care for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping veterans care for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping veterans care for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping veterans care for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping veterans care for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping veterans care for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping veterans care for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping veterans care for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping veterans care for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping veterans care for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping veterans care for 2022-12 as it has already been mined
# Mining tweets for keyword: medical debt
# Mining tweets for month: 2021-01
# Skipping medical debt for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping medical debt for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping medical debt for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping medical debt for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping medical debt for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping medical debt for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping medical debt for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping medical debt for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping medical debt for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping medical debt for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping medical debt for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping medical debt for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping medical debt for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping medical debt for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping medical debt for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping medical debt for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping medical debt for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping medical debt for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping medical debt for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping medical debt for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping medical debt for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping medical debt for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping medical debt for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping medical debt for 2022-12 as it has already been mined
# Mining tweets for keyword: medical Cost
# Mining tweets for month: 2021-01
# Skipping medical Cost for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping medical Cost for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping medical Cost for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping medical Cost for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping medical Cost for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping medical Cost for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping medical Cost for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping medical Cost for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping medical Cost for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping medical Cost for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping medical Cost for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping medical Cost for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping medical Cost for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping medical Cost for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping medical Cost for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping medical Cost for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping medical Cost for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping medical Cost for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping medical Cost for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping medical Cost for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping medical Cost for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping medical Cost for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping medical Cost for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping medical Cost for 2022-12 as it has already been mined
# Mining tweets for keyword: #Medicaid
# Mining tweets for month: 2021-01
# Skipping #Medicaid for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping #Medicaid for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping #Medicaid for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping #Medicaid for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping #Medicaid for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping #Medicaid for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping #Medicaid for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping #Medicaid for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping #Medicaid for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping #Medicaid for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping #Medicaid for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping #Medicaid for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping #Medicaid for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping #Medicaid for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping #Medicaid for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping #Medicaid for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping #Medicaid for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping #Medicaid for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping #Medicaid for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping #Medicaid for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping #Medicaid for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping #Medicaid for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping #Medicaid for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping #Medicaid for 2022-12 as it has already been mined
# Mining tweets for keyword: #medicare
# Mining tweets for month: 2021-01
# Skipping #medicare for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping #medicare for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping #medicare for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping #medicare for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping #medicare for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping #medicare for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping #medicare for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping #medicare for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping #medicare for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping #medicare for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping #medicare for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping #medicare for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping #medicare for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping #medicare for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping #medicare for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping #medicare for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping #medicare for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping #medicare for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping #medicare for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping #medicare for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping #medicare for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping #medicare for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping #medicare for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping #medicare for 2022-12 as it has already been mined
# Mining tweets for keyword: #tricare
# Mining tweets for month: 2021-01
# Skipping #tricare for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping #tricare for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping #tricare for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping #tricare for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping #tricare for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping #tricare for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping #tricare for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping #tricare for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping #tricare for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping #tricare for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping #tricare for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping #tricare for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping #tricare for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping #tricare for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping #tricare for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping #tricare for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping #tricare for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping #tricare for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping #tricare for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping #tricare for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping #tricare for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping #tricare for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping #tricare for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping #tricare for 2022-12 as it has already been mined
# Mining tweets for keyword: #veterans care
# Mining tweets for month: 2021-01
# Skipping #veterans care for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping #veterans care for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping #veterans care for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping #veterans care for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping #veterans care for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping #veterans care for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping #veterans care for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping #veterans care for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping #veterans care for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping #veterans care for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping #veterans care for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping #veterans care for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping #veterans care for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping #veterans care for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping #veterans care for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping #veterans care for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping #veterans care for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping #veterans care for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping #veterans care for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping #veterans care for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping #veterans care for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping #veterans care for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping #veterans care for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping #veterans care for 2022-12 as it has already been mined
# Mining tweets for keyword: #medicaldebt
# Mining tweets for month: 2021-01
# Skipping #medicaldebt for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping #medicaldebt for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping #medicaldebt for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping #medicaldebt for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping #medicaldebt for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping #medicaldebt for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping #medicaldebt for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping #medicaldebt for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping #medicaldebt for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping #medicaldebt for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping #medicaldebt for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping #medicaldebt for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping #medicaldebt for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping #medicaldebt for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping #medicaldebt for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping #medicaldebt for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping #medicaldebt for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping #medicaldebt for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping #medicaldebt for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping #medicaldebt for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping #medicaldebt for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping #medicaldebt for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping #medicaldebt for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping #medicaldebt for 2022-12 as it has already been mined
# Mining tweets for keyword: #medicalcost
# Mining tweets for month: 2021-01
# Skipping #medicalcost for 2021-01 as it has already been mined
# Mining tweets for month: 2021-02
# Skipping #medicalcost for 2021-02 as it has already been mined
# Mining tweets for month: 2021-03
# Skipping #medicalcost for 2021-03 as it has already been mined
# Mining tweets for month: 2021-04
# Skipping #medicalcost for 2021-04 as it has already been mined
# Mining tweets for month: 2021-05
# Skipping #medicalcost for 2021-05 as it has already been mined
# Mining tweets for month: 2021-06
# Skipping #medicalcost for 2021-06 as it has already been mined
# Mining tweets for month: 2021-07
# Skipping #medicalcost for 2021-07 as it has already been mined
# Mining tweets for month: 2021-08
# Skipping #medicalcost for 2021-08 as it has already been mined
# Mining tweets for month: 2021-09
# Skipping #medicalcost for 2021-09 as it has already been mined
# Mining tweets for month: 2021-10
# Skipping #medicalcost for 2021-10 as it has already been mined
# Mining tweets for month: 2021-11
# Skipping #medicalcost for 2021-11 as it has already been mined
# Mining tweets for month: 2021-12
# Skipping #medicalcost for 2021-12 as it has already been mined
# Mining tweets for month: 2022-01
# Skipping #medicalcost for 2022-01 as it has already been mined
# Mining tweets for month: 2022-02
# Skipping #medicalcost for 2022-02 as it has already been mined
# Mining tweets for month: 2022-03
# Skipping #medicalcost for 2022-03 as it has already been mined
# Mining tweets for month: 2022-04
# Skipping #medicalcost for 2022-04 as it has already been mined
# Mining tweets for month: 2022-05
# Skipping #medicalcost for 2022-05 as it has already been mined
# Mining tweets for month: 2022-06
# Skipping #medicalcost for 2022-06 as it has already been mined
# Mining tweets for month: 2022-07
# Skipping #medicalcost for 2022-07 as it has already been mined
# Mining tweets for month: 2022-08
# Skipping #medicalcost for 2022-08 as it has already been mined
# Mining tweets for month: 2022-09
# Skipping #medicalcost for 2022-09 as it has already been mined
# Mining tweets for month: 2022-10
# Skipping #medicalcost for 2022-10 as it has already been mined
# Mining tweets for month: 2022-11
# Skipping #medicalcost for 2022-11 as it has already been mined
# Mining tweets for month: 2022-12
# Skipping #medicalcost for 2022-12 as it has already been mined
